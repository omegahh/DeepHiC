# %% [markdown]
# # Miscellaneous Figures for Figure1

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from utilities import mkdir
from utils.viz import heatmap

# %%
work_dir = '/data/RaoHiC/results/MISC/fig1'
mkdir(work_dir)

# %% [markdown]
# ## 1. Fig.1B

# %%
data = np.load('/data/RaoHiC/predict/GM12878/predict_chr17_40kb.npz')

orighic = data['hic']
downhic = data['downhic']

orighic = orighic / np.max(orighic)
downhic = downhic / np.max(downhic)

orighic_17 = orighic[7060:7460, 7060:7460]
downhic_17 = downhic[7060:7460, 7060:7460]

# %%
fig, ax = plt.subplots(figsize=[6,6])
heatmap(ax, downhic_17, show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p1.svg')
eps_file = os.path.join(work_dir, f'fig1b_p1.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, downhic_17[10:50,40:80], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p21.svg')
eps_file = os.path.join(work_dir, f'fig1b_p21.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, downhic_17[80:120,90:130], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p22.svg')
eps_file = os.path.join(work_dir, f'fig1b_p22.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, downhic_17[150:190,150:190], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p23.svg')
eps_file = os.path.join(work_dir, f'fig1b_p23.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, downhic_17[250:290,190:230], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p24.svg')
eps_file = os.path.join(work_dir, f'fig1b_p24.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, downhic_17[340:380,300:340], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p25.svg')
eps_file = os.path.join(work_dir, f'fig1b_p25.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[6,6])
heatmap(ax, orighic_17, show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p4.svg')
eps_file = os.path.join(work_dir, f'fig1b_p4.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, orighic_17[10:50,40:80], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p31.svg')
eps_file = os.path.join(work_dir, f'fig1b_p31.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, orighic_17[80:120,90:130], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p32.svg')
eps_file = os.path.join(work_dir, f'fig1b_p32.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, orighic_17[150:190,150:190], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p33.svg')
eps_file = os.path.join(work_dir, f'fig1b_p33.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, orighic_17[250:290,190:230], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p34.svg')
eps_file = os.path.join(work_dir, f'fig1b_p34.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
fig, ax = plt.subplots(figsize=[3,3])
heatmap(ax, orighic_17[340:380,300:340], show_bar=False, close_ticks=True)
svg_file = os.path.join(work_dir, f'fig1b_p35.svg')
eps_file = os.path.join(work_dir, f'fig1b_p35.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %% [markdown]
# ## Fig. 1C

# %%
work_dir = '/data/RaoHiC/results/MISC'

# %%
ssim_res = np.loadtxt('/data/RaoHiC/results/model_result/swish_result_main.txt')

# %%
fig, ax = plt.subplots(figsize=[5,4])
ax.plot(ssim_res)
ax.set_title('SSIM score in test set', fontsize='xx-large')
ax.set_xlabel('Training epoch', fontsize='x-large')
ax.set_ylabel('SSIM score', fontsize='x-large')
svg_file = os.path.join(work_dir, f'fig1c_ssim.svg')
eps_file = os.path.join(work_dir, f'fig1c_ssim.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %% [markdown]
# ## Supp Figs.

# %%
loss_res = np.loadtxt('/data/RaoHiC/results/model_result/loss_swish_result.txt')

# %%
fig, ax = plt.subplots()
ax.plot(loss_res[:,0], label='Training set')
ax.plot(loss_res[:,1], label='Test set')
ax.set_title('The trends of $G$ loss', fontsize='xx-large')
ax.set_xlabel('Training epoch', fontsize='x-large')
ax.set_ylabel('Loss', fontsize='x-large')
plt.legend(fontsize='large')
svg_file = os.path.join(work_dir, f'supp_fig_loss.svg')
eps_file = os.path.join(work_dir, f'supp_fig_loss.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
ssim_res = np.loadtxt('/data/RaoHiC/results/model_result/regression_ssim_result.txt')

# %%
fig, ax = plt.subplots()
ax.plot(ssim_res)
ax.set_title('SSIM trends without GAN model', fontsize='xx-large')
ax.set_xlabel('Training epoch', fontsize='x-large')
ax.set_ylabel('SSIM score', fontsize='x-large')
svg_file = os.path.join(work_dir, f'supp_fig_regression_failed.svg')
eps_file = os.path.join(work_dir, f'supp_fig_regression_failed.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
ssim_res1 = np.loadtxt('/data/RaoHiC/results/model_result/swish_ssim_0102.txt')
ssim_res2 = np.loadtxt('/data/RaoHiC/results/model_result/swish_ssim_0103.txt')
ssim_res3 = np.loadtxt('/data/RaoHiC/results/model_result/swish_ssim_0111.txt')
ssim_res4 = np.loadtxt('/data/RaoHiC/results/model_result/swish_ssim_0116.txt')

# %%
plt.tight_layout()
fig, ax = plt.subplots(ncols=2, figsize=[16, 5])
ax[0].plot(ssim_res1)
ax[0].set_title('Training on chr 1-8 & 12-18', fontsize='xx-large')
ax[0].set_xlabel('Training epoch', fontsize='x-large')
ax[0].set_ylabel('SSIM score on test set', fontsize='x-large')
ax[1].plot(ssim_res2)
ax[1].set_title('Training on chr 9-22', fontsize='xx-large')
ax[1].set_xlabel('Training epoch', fontsize='x-large')
ax[1].set_ylabel('SSIM score on test set', fontsize='x-large')
svg_file = os.path.join(work_dir, f'supp_fig_other_ssim1.svg')
eps_file = os.path.join(work_dir, f'supp_fig_other_ssim1.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')

# %%
plt.tight_layout()
fig, ax = plt.subplots(ncols=2, figsize=[16, 5])
ax[0].plot(ssim_res3)
ax[0].set_title('Training on chr 4-17', fontsize='xx-large')
ax[0].set_xlabel('Training epoch', fontsize='x-large')
ax[0].set_ylabel('SSIM score on test set', fontsize='x-large')
ax[1].plot(ssim_res4)
ax[1].set_title('Training on chr 1-14', fontsize='xx-large')
ax[1].set_xlabel('Training epoch', fontsize='x-large')
ax[1].set_ylabel('SSIM score on test set', fontsize='x-large')
svg_file = os.path.join(work_dir, f'supp_fig_other_ssim2.svg')
eps_file = os.path.join(work_dir, f'supp_fig_other_ssim2.eps')
fig.savefig(svg_file, format='svg')
fig.savefig(eps_file, format='eps')
